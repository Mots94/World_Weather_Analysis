# %%
import pandas as pd
import requests
import numpy as np
import time
from citipy import citipy
from config import weather_api_key

# %%
# Create a new set of 2000 random lats and longs

lats = np.random.uniform(-90.000, 90.000, size=2000)

longs = np.random.uniform(-180.000, 180.000, size=2000)

lat_longs = zip(lats, longs)

lat_longs

# %%
# Create new list to hold city names

coordinates = list(lat_longs)

cities = []

for coordinate in coordinates:

    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:

        cities.append(city)

len(cities)
# Out:
# 742

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=standard&appid=" + weather_api_key

# %%
# Empty list to hold weather data
city_data = []

print('Beginning Data Retrieval     ')

print('-----------------------------')

# Create counters
record_count = 1

set_count = 1

# Loop through all cities in city list
 
for i, city in enumerate(cities):

    # Grouping cities in set of 50 for logging
    if (i % 50 == 0 and i >= 50):

        set_count += 1

        record_count = 1

        time.sleep(60)

    # Create endpoint URL for each city
    city_url = url + '&q=' + city.replace(' ','+')

    # Log the URL, record, and set numbers and the city
    print(f'Processing record {record_count} of set {set_count} | {city}')

    # Add 1 to record count
    record_count += 1

    try:

        city_weather = requests.get(city_url).json()

        country_name = city_weather['sys']['country']

        city_lat = city_weather['coord']['lat']

        city_long = city_weather['coord']['lon']

        city_max_temp = city_weather['main']['temp_max']

        city_humidity = city_weather['main']['humidity']

        city_clouds = city_weather['clouds']['all']

        city_wind = city_weather['wind']['speed']

        city_description = city_weather['weather'][0]['description']

        city_data.append({'City': city.title(),
                    'Country': country_name,
                    'Lat': city_lat,
                    'Long': city_long,
                    'Max Temp': city_max_temp,
                    'Humidity': city_humidity,
                    'Cloudiness': city_clouds,
                    'Wind Speed': city_wind,
                    'Current Description': city_description})

    except:

        print('City not found. Skipping...')

        pass

# Indicate the data loading is complete

print('-----------------------------')

print('Data Retrieval Complete      ')

print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | hermanus
# Processing record 2 of set 1 | castro
# Processing record 3 of set 1 | busselton
# Processing record 4 of set 1 | lolua
# City not found. Skipping...
# Processing record 5 of set 1 | zhanaozen
# Processing record 6 of set 1 | mataura
# Processing record 7 of set 1 | winslow
# Processing record 8 of set 1 | cayenne
# Processing record 9 of set 1 | ondjiva
# Processing record 10 of set 1 | sao filipe
# Processing record 11 of set 1 | mehran
# Processing record 12 of set 1 | dikson
# Processing record 13 of set 1 | maku
# Processing record 14 of set 1 | lompoc
# Processing record 15 of set 1 | vaini
# Processing record 16 of set 1 | ngukurr
# City not found. Skipping...
# Processing record 17 of set 1 | yining
# Processing record 18 of set 1 | barrow
# Processing record 19 of set 1 | chuy
# Processing record 20 of set 1 | manaure
# Processing record 21 of set 1 | mar del plata
# Processing record 22 of set 1 | lima
# Processing record 23 of set 1 | flin flon
# Processing record 24 of set 1 | palabuhanratu
# City not found. Skipping...
# Processing record 25 of set 1 | ibra
# Processing record 26 of set 1 | nizhneyansk
# City not found. Skipping...
# Processing record 27 of set 1 | beira
# Processing record 28 of set 1 | rikitea
# Processing record 29 of set 1 | grand gaube
# Processing record 30 of set 1 | port alfred
# Processing record 31 of set 1 | gornopravdinsk
# Processing record 32 of set 1 | karaman
# Processing record 33 of set 1 | payson
# Processing record 34 of set 1 | saskylakh
# Processing record 35 of set 1 | dunedin
# Processing record 36 of set 1 | boa vista
# Processing record 37 of set 1 | marmora
# Processing record 38 of set 1 | kapaa
# Processing record 39 of set 1 | ushuaia
# Processing record 40 of set 1 | albany
# Processing record 41 of set 1 | hobart
# Processing record 42 of set 1 | soyo
# Processing record 43 of set 1 | kushiro
# Processing record 44 of set 1 | tumannyy
# City not found. Skipping...
# Processing record 45 of set 1 | kolvereid
# Processing record 46 of set 1 | duluth
# Processing record 47 of set 1 | tsiroanomandidy
# Processing record 48 of set 1 | marsabit
# Processing record 49 of set 1 | cabedelo
# Processing record 50 of set 1 | faanui
# Processing record 1 of set 2 | tuktoyaktuk
# Processing record 2 of set 2 | vallenar
# Processing record 3 of set 2 | ribeira grande
# Processing record 4 of set 2 | jamestown
# Processing record 5 of set 2 | riyadh
# Processing record 6 of set 2 | taolanaro
# City not found. Skipping...
# Processing record 7 of set 2 | goure
# Processing record 8 of set 2 | chubbuck
# Processing record 9 of set 2 | cape town
# Processing record 10 of set 2 | uvat
# Processing record 11 of set 2 | diamantino
# Processing record 12 of set 2 | san ignacio
# Processing record 13 of set 2 | pisco
# Processing record 14 of set 2 | henties bay
# Processing record 15 of set 2 | bloomingdale
# Processing record 16 of set 2 | bako
# Processing record 17 of set 2 | airai
# Processing record 18 of set 2 | esperance
# Processing record 19 of set 2 | gosainganj
# Processing record 20 of set 2 | mayo
# Processing record 21 of set 2 | husavik
# Processing record 22 of set 2 | nikolskoye
# Processing record 23 of set 2 | awjilah
# Processing record 24 of set 2 | kenora
# Processing record 25 of set 2 | bredasdorp
# Processing record 26 of set 2 | aleksandrov gay
# Processing record 27 of set 2 | iida
# Processing record 28 of set 2 | butaritari
# Processing record 29 of set 2 | san cristobal
# Processing record 30 of set 2 | cooma
# Processing record 31 of set 2 | longyearbyen
# Processing record 32 of set 2 | priargunsk
# Processing record 33 of set 2 | bluff
# Processing record 34 of set 2 | tamworth
# Processing record 35 of set 2 | touros
# Processing record 36 of set 2 | nanortalik
# Processing record 37 of set 2 | esil
# Processing record 38 of set 2 | leh
# Processing record 39 of set 2 | thompson
# Processing record 40 of set 2 | marcona
# City not found. Skipping...
# Processing record 41 of set 2 | kjollefjord
# Processing record 42 of set 2 | tadine
# Processing record 43 of set 2 | pevek
# Processing record 44 of set 2 | lavrentiya
# Processing record 45 of set 2 | grand river south east
# City not found. Skipping...
# Processing record 46 of set 2 | te anau
# Processing record 47 of set 2 | arraial do cabo
# Processing record 48 of set 2 | rawson
# Processing record 49 of set 2 | taltal
# Processing record 50 of set 2 | acapulco
# Processing record 1 of set 3 | chokurdakh
# Processing record 2 of set 3 | sokone
# Processing record 3 of set 3 | kaitangata
# Processing record 4 of set 3 | paita
# Processing record 5 of set 3 | punta arenas
# Processing record 6 of set 3 | provideniya
# Processing record 7 of set 3 | simoes
# Processing record 8 of set 3 | nanyamba
# Processing record 9 of set 3 | vaitupu
# City not found. Skipping...
# Processing record 10 of set 3 | carnarvon
# Processing record 11 of set 3 | dubbo
# Processing record 12 of set 3 | mys shmidta
# City not found. Skipping...
# Processing record 13 of set 3 | qaanaaq
# Processing record 14 of set 3 | trogir
# Processing record 15 of set 3 | anloga
# Processing record 16 of set 3 | peceneaga
# Processing record 17 of set 3 | attawapiskat
# City not found. Skipping...
# Processing record 18 of set 3 | carutapera
# Processing record 19 of set 3 | altay
# Processing record 20 of set 3 | merrill
# Processing record 21 of set 3 | mairwa
# Processing record 22 of set 3 | lebu
# Processing record 23 of set 3 | faya
# Processing record 24 of set 3 | mayumba
# Processing record 25 of set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing record 26 of set 3 | palmer
# Processing record 27 of set 3 | bubaque
# Processing record 28 of set 3 | byron bay
# Processing record 29 of set 3 | goycay
# City not found. Skipping...
# Processing record 30 of set 3 | babu
# Processing record 31 of set 3 | samusu
# City not found. Skipping...
# Processing record 32 of set 3 | iqaluit
# Processing record 33 of set 3 | mehamn
# Processing record 34 of set 3 | upernavik
# Processing record 35 of set 3 | santa isabel do rio negro
# Processing record 36 of set 3 | batagay-alyta
# Processing record 37 of set 3 | alofi
# Processing record 38 of set 3 | saint-philippe
# Processing record 39 of set 3 | changping
# Processing record 40 of set 3 | aflu
# City not found. Skipping...
# Processing record 41 of set 3 | new norfolk
# Processing record 42 of set 3 | kieta
# Processing record 43 of set 3 | jurm
# Processing record 44 of set 3 | laguna de perlas
# Processing record 45 of set 3 | verkhoyansk
# Processing record 46 of set 3 | port elizabeth
# Processing record 47 of set 3 | gejiu
# Processing record 48 of set 3 | srednekolymsk
# Processing record 49 of set 3 | ola
# Processing record 50 of set 3 | hilo
# Processing record 1 of set 4 | papara
# Processing record 2 of set 4 | areosa
# Processing record 3 of set 4 | caravelas
# Processing record 4 of set 4 | leningradskiy
# Processing record 5 of set 4 | vanimo
# Processing record 6 of set 4 | sandeid
# Processing record 7 of set 4 | chimbote
# Processing record 8 of set 4 | acajutla
# Processing record 9 of set 4 | iracoubo
# Processing record 10 of set 4 | walvis bay
# Processing record 11 of set 4 | sosnogorsk
# Processing record 12 of set 4 | kavieng
# Processing record 13 of set 4 | kuytun
# Processing record 14 of set 4 | tual
# Processing record 15 of set 4 | yar-sale
# Processing record 16 of set 4 | komsomolskiy
# Processing record 17 of set 4 | boende
# Processing record 18 of set 4 | svetlyy
# Processing record 19 of set 4 | fairbanks
# Processing record 20 of set 4 | birao
# Processing record 21 of set 4 | east london
# Processing record 22 of set 4 | cherskiy
# Processing record 23 of set 4 | tiarei
# Processing record 24 of set 4 | san quintin
# Processing record 25 of set 4 | viligili
# City not found. Skipping...
# Processing record 26 of set 4 | khatanga
# Processing record 27 of set 4 | bonthe
# Processing record 28 of set 4 | yellowknife
# Processing record 29 of set 4 | souillac
# Processing record 30 of set 4 | talnakh
# Processing record 31 of set 4 | bethel
# Processing record 32 of set 4 | margate
# Processing record 33 of set 4 | poum
# Processing record 34 of set 4 | mtwara
# Processing record 35 of set 4 | comodoro rivadavia
# Processing record 36 of set 4 | lorengau
# Processing record 37 of set 4 | amsterdam
# Processing record 38 of set 4 | constitucion
# Processing record 39 of set 4 | turka
# Processing record 40 of set 4 | zakharovo
# Processing record 41 of set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing record 42 of set 4 | tucumcari
# Processing record 43 of set 4 | lagoa
# Processing record 44 of set 4 | yanan
# City not found. Skipping...
# Processing record 45 of set 4 | ilulissat
# Processing record 46 of set 4 | north bend
# Processing record 47 of set 4 | rawah
# Processing record 48 of set 4 | klaksvik
# Processing record 49 of set 4 | yatou
# Processing record 50 of set 4 | tasiilaq
# Processing record 1 of set 5 | vrangel
# Processing record 2 of set 5 | montepuez
# Processing record 3 of set 5 | belushya guba
# City not found. Skipping...
# Processing record 4 of set 5 | vardo
# Processing record 5 of set 5 | kodiak
# Processing record 6 of set 5 | namibe
# Processing record 7 of set 5 | broome
# Processing record 8 of set 5 | mercedes
# Processing record 9 of set 5 | cabo san lucas
# Processing record 10 of set 5 | mount isa
# Processing record 11 of set 5 | bitung
# Processing record 12 of set 5 | moreira sales
# Processing record 13 of set 5 | show low
# Processing record 14 of set 5 | esmeralda
# Processing record 15 of set 5 | otane
# Processing record 16 of set 5 | algiers
# Processing record 17 of set 5 | barentsburg
# City not found. Skipping...
# Processing record 18 of set 5 | severo-kurilsk
# Processing record 19 of set 5 | salalah
# Processing record 20 of set 5 | general roca
# Processing record 21 of set 5 | puerto berrio
# Processing record 22 of set 5 | hithadhoo
# Processing record 23 of set 5 | sentyabrskiy
# City not found. Skipping...
# Processing record 24 of set 5 | linping
# Processing record 25 of set 5 | trairi
# Processing record 26 of set 5 | port hedland
# Processing record 27 of set 5 | honningsvag
# Processing record 28 of set 5 | sabha
# Processing record 29 of set 5 | shingu
# Processing record 30 of set 5 | sainte-suzanne
# Processing record 31 of set 5 | cidreira
# Processing record 32 of set 5 | emborion
# Processing record 33 of set 5 | mezen
# Processing record 34 of set 5 | saleaula
# City not found. Skipping...
# Processing record 35 of set 5 | damietta
# Processing record 36 of set 5 | san miguel
# Processing record 37 of set 5 | panguipulli
# Processing record 38 of set 5 | katsuura
# Processing record 39 of set 5 | ancud
# Processing record 40 of set 5 | alice town
# Processing record 41 of set 5 | puerto ayora
# Processing record 42 of set 5 | bathsheba
# Processing record 43 of set 5 | hovd
# Processing record 44 of set 5 | juneau
# Processing record 45 of set 5 | olafsvik
# Processing record 46 of set 5 | coahuayana
# Processing record 47 of set 5 | bud
# Processing record 48 of set 5 | parainen
# Processing record 49 of set 5 | road town
# Processing record 50 of set 5 | moose factory
# Processing record 1 of set 6 | jurado
# Processing record 2 of set 6 | tromso
# Processing record 3 of set 6 | sulphur
# Processing record 4 of set 6 | storforshei
# Processing record 5 of set 6 | whitehorse
# Processing record 6 of set 6 | san policarpo
# Processing record 7 of set 6 | port-gentil
# Processing record 8 of set 6 | adrar
# Processing record 9 of set 6 | shestakovo
# Processing record 10 of set 6 | vila velha
# Processing record 11 of set 6 | weligama
# Processing record 12 of set 6 | kasane
# Processing record 13 of set 6 | sinnamary
# Processing record 14 of set 6 | etchoropo
# Processing record 15 of set 6 | zhigansk
# Processing record 16 of set 6 | klyuchi
# Processing record 17 of set 6 | praia da vitoria
# Processing record 18 of set 6 | kerema
# Processing record 19 of set 6 | kamenskoye
# City not found. Skipping...
# Processing record 20 of set 6 | saint-francois
# Processing record 21 of set 6 | ponta delgada
# Processing record 22 of set 6 | huarmey
# Processing record 23 of set 6 | shibetsu
# Processing record 24 of set 6 | ugoofaaru
# Processing record 25 of set 6 | ponta do sol
# Processing record 26 of set 6 | pascagoula
# Processing record 27 of set 6 | saint anthony
# Processing record 28 of set 6 | dovolnoye
# Processing record 29 of set 6 | pozo colorado
# Processing record 30 of set 6 | atuona
# Processing record 31 of set 6 | abilene
# Processing record 32 of set 6 | chengde
# Processing record 33 of set 6 | tsihombe
# City not found. Skipping...
# Processing record 34 of set 6 | chinsali
# Processing record 35 of set 6 | pilar
# Processing record 36 of set 6 | nyurba
# Processing record 37 of set 6 | cao bang
# Processing record 38 of set 6 | tuatapere
# Processing record 39 of set 6 | majene
# Processing record 40 of set 6 | nizhniy odes
# Processing record 41 of set 6 | roma
# Processing record 42 of set 6 | padang
# Processing record 43 of set 6 | tucurui
# Processing record 44 of set 6 | marsh harbour
# Processing record 45 of set 6 | tatawin
# Processing record 46 of set 6 | charters towers
# Processing record 47 of set 6 | port hardy
# Processing record 48 of set 6 | guerrero negro
# Processing record 49 of set 6 | manokwari
# Processing record 50 of set 6 | zlitan
# Processing record 1 of set 7 | nova olinda do norte
# Processing record 2 of set 7 | soe
# Processing record 3 of set 7 | bouna
# Processing record 4 of set 7 | coruripe
# Processing record 5 of set 7 | puerto baquerizo moreno
# Processing record 6 of set 7 | hervey bay
# Processing record 7 of set 7 | leshukonskoye
# Processing record 8 of set 7 | codrington
# Processing record 9 of set 7 | spruce grove
# Processing record 10 of set 7 | nemuro
# Processing record 11 of set 7 | shelburne
# Processing record 12 of set 7 | kelvington
# Processing record 13 of set 7 | tiznit
# Processing record 14 of set 7 | monrovia
# Processing record 15 of set 7 | muros
# Processing record 16 of set 7 | zuenoula
# Processing record 17 of set 7 | firminy
# Processing record 18 of set 7 | dera gopipur
# Processing record 19 of set 7 | coquimbo
# Processing record 20 of set 7 | sorong
# Processing record 21 of set 7 | dongsheng
# Processing record 22 of set 7 | amderma
# City not found. Skipping...
# Processing record 23 of set 7 | gushikawa
# Processing record 24 of set 7 | mahebourg
# Processing record 25 of set 7 | pochutla
# Processing record 26 of set 7 | saint joseph
# Processing record 27 of set 7 | tubigan
# Processing record 28 of set 7 | bayanday
# Processing record 29 of set 7 | rize
# Processing record 30 of set 7 | moranbah
# Processing record 31 of set 7 | salisbury
# Processing record 32 of set 7 | victoria
# Processing record 33 of set 7 | haimen
# Processing record 34 of set 7 | long xuyen
# Processing record 35 of set 7 | saint george
# Processing record 36 of set 7 | ariquemes
# Processing record 37 of set 7 | yerbogachen
# Processing record 38 of set 7 | ambilobe
# Processing record 39 of set 7 | sisimiut
# Processing record 40 of set 7 | gamba
# Processing record 41 of set 7 | tiksi
# Processing record 42 of set 7 | westport
# Processing record 43 of set 7 | solovetskiy
# City not found. Skipping...
# Processing record 44 of set 7 | mehtar lam
# Processing record 45 of set 7 | hasaki
# Processing record 46 of set 7 | avarua
# Processing record 47 of set 7 | victor harbor
# Processing record 48 of set 7 | korla
# Processing record 49 of set 7 | kropotkin
# Processing record 50 of set 7 | shenjiamen
# Processing record 1 of set 8 | aklavik
# Processing record 2 of set 8 | tsentralnyy
# City not found. Skipping...
# Processing record 3 of set 8 | marquette
# Processing record 4 of set 8 | necochea
# Processing record 5 of set 8 | kaihua
# Processing record 6 of set 8 | ilheus
# Processing record 7 of set 8 | erenhot
# Processing record 8 of set 8 | batsfjord
# Processing record 9 of set 8 | vao
# Processing record 10 of set 8 | itapuranga
# Processing record 11 of set 8 | sarangani
# Processing record 12 of set 8 | kenai
# Processing record 13 of set 8 | kasempa
# Processing record 14 of set 8 | vila franca do campo
# Processing record 15 of set 8 | cochrane
# Processing record 16 of set 8 | seoul
# Processing record 17 of set 8 | alta floresta
# Processing record 18 of set 8 | luganville
# Processing record 19 of set 8 | hamilton
# Processing record 20 of set 8 | aulnoye-aymeries
# Processing record 21 of set 8 | half moon bay
# Processing record 22 of set 8 | berlevag
# Processing record 23 of set 8 | richards bay
# Processing record 24 of set 8 | golden
# Processing record 25 of set 8 | ouesso
# Processing record 26 of set 8 | khvastovichi
# Processing record 27 of set 8 | torbay
# Processing record 28 of set 8 | narbonne
# Processing record 29 of set 8 | broken hill
# Processing record 30 of set 8 | hami
# Processing record 31 of set 8 | kibre mengist
# Processing record 32 of set 8 | camacha
# Processing record 33 of set 8 | kodinsk
# Processing record 34 of set 8 | krasyliv
# Processing record 35 of set 8 | luderitz
# Processing record 36 of set 8 | georgetown
# Processing record 37 of set 8 | hobyo
# Processing record 38 of set 8 | carroll
# Processing record 39 of set 8 | figeac
# Processing record 40 of set 8 | ozernovskiy
# Processing record 41 of set 8 | chapais
# Processing record 42 of set 8 | clyde river
# Processing record 43 of set 8 | surt
# Processing record 44 of set 8 | lagunas
# Processing record 45 of set 8 | punta alta
# Processing record 46 of set 8 | takoradi
# Processing record 47 of set 8 | assiniboia
# Processing record 48 of set 8 | ukiah
# Processing record 49 of set 8 | gbarnga
# Processing record 50 of set 8 | vestmannaeyjar
# Processing record 1 of set 9 | tilichiki
# Processing record 2 of set 9 | morondava
# Processing record 3 of set 9 | garowe
# Processing record 4 of set 9 | meulaboh
# Processing record 5 of set 9 | el cobre
# Processing record 6 of set 9 | asau
# Processing record 7 of set 9 | durango
# Processing record 8 of set 9 | embonas
# Processing record 9 of set 9 | havoysund
# Processing record 10 of set 9 | taga
# Processing record 11 of set 9 | norman wells
# Processing record 12 of set 9 | padilla
# Processing record 13 of set 9 | trail
# Processing record 14 of set 9 | naryan-mar
# Processing record 15 of set 9 | raahe
# Processing record 16 of set 9 | kavaratti
# Processing record 17 of set 9 | saldanha
# Processing record 18 of set 9 | praya
# Processing record 19 of set 9 | sandwick
# Processing record 20 of set 9 | mujiayingzi
# Processing record 21 of set 9 | fort saint james
# Processing record 22 of set 9 | porto novo
# Processing record 23 of set 9 | cockburn town
# Processing record 24 of set 9 | huilong
# Processing record 25 of set 9 | marawi
# Processing record 26 of set 9 | badgam
# City not found. Skipping...
# Processing record 27 of set 9 | suntar
# Processing record 28 of set 9 | grenfell
# Processing record 29 of set 9 | kahului
# Processing record 30 of set 9 | port angeles
# Processing record 31 of set 9 | college
# Processing record 32 of set 9 | mrirt
# City not found. Skipping...
# Processing record 33 of set 9 | karpuninskiy
# City not found. Skipping...
# Processing record 34 of set 9 | galiwinku
# City not found. Skipping...
# Processing record 35 of set 9 | pavlivka
# Processing record 36 of set 9 | ostrovnoy
# Processing record 37 of set 9 | san jorge
# Processing record 38 of set 9 | moses lake
# Processing record 39 of set 9 | petropavlovsk-kamchatskiy
# Processing record 40 of set 9 | kutum
# Processing record 41 of set 9 | port shepstone
# Processing record 42 of set 9 | solnechnyy
# Processing record 43 of set 9 | bodden town
# Processing record 44 of set 9 | russell
# Processing record 45 of set 9 | hammerfest
# Processing record 46 of set 9 | dudinka
# Processing record 47 of set 9 | talaya
# Processing record 48 of set 9 | port hawkesbury
# Processing record 49 of set 9 | coihaique
# Processing record 50 of set 9 | namatanai
# Processing record 1 of set 10 | santo antonio do sudoeste
# Processing record 2 of set 10 | ballina
# Processing record 3 of set 10 | chase
# Processing record 4 of set 10 | charcas
# Processing record 5 of set 10 | ladario
# Processing record 6 of set 10 | jardim
# Processing record 7 of set 10 | bambous virieux
# Processing record 8 of set 10 | tautira
# Processing record 9 of set 10 | oranjemund
# Processing record 10 of set 10 | bafq
# Processing record 11 of set 10 | hualmay
# Processing record 12 of set 10 | malwan
# City not found. Skipping...
# Processing record 13 of set 10 | rolim de moura
# City not found. Skipping...
# Processing record 14 of set 10 | kijang
# Processing record 15 of set 10 | ambodifototra
# City not found. Skipping...
# Processing record 16 of set 10 | kruisfontein
# Processing record 17 of set 10 | christchurch
# Processing record 18 of set 10 | sabang
# Processing record 19 of set 10 | portland
# Processing record 20 of set 10 | concordia
# Processing record 21 of set 10 | sawai madhopur
# Processing record 22 of set 10 | ostuacan
# Processing record 23 of set 10 | southampton
# Processing record 24 of set 10 | inhambane
# Processing record 25 of set 10 | makakilo city
# Processing record 26 of set 10 | kualakapuas
# Processing record 27 of set 10 | babanusah
# City not found. Skipping...
# Processing record 28 of set 10 | iringa
# Processing record 29 of set 10 | nongpoh
# Processing record 30 of set 10 | mutsamudu
# City not found. Skipping...
# Processing record 31 of set 10 | bardiyah
# Processing record 32 of set 10 | anjozorobe
# Processing record 33 of set 10 | traian
# Processing record 34 of set 10 | rio cuarto
# Processing record 35 of set 10 | la seyne-sur-mer
# Processing record 36 of set 10 | ternate
# Processing record 37 of set 10 | trelew
# Processing record 38 of set 10 | shenkursk
# Processing record 39 of set 10 | thinadhoo
# Processing record 40 of set 10 | achisay
# City not found. Skipping...
# Processing record 41 of set 10 | san patricio
# Processing record 42 of set 10 | pacific grove
# Processing record 43 of set 10 | yumen
# Processing record 44 of set 10 | zyryanovsk
# Processing record 45 of set 10 | jistebnice
# Processing record 46 of set 10 | kumluca
# Processing record 47 of set 10 | werda
# Processing record 48 of set 10 | puerto rico
# Processing record 49 of set 10 | camocim
# Processing record 50 of set 10 | maymyo
# Processing record 1 of set 11 | beringovskiy
# Processing record 2 of set 11 | matara
# Processing record 3 of set 11 | mislinja
# Processing record 4 of set 11 | bengkulu
# Processing record 5 of set 11 | banff
# Processing record 6 of set 11 | kautokeino
# Processing record 7 of set 11 | sherbakul
# Processing record 8 of set 11 | los llanos de aridane
# Processing record 9 of set 11 | vilhena
# Processing record 10 of set 11 | keti bandar
# Processing record 11 of set 11 | malakal
# Processing record 12 of set 11 | okha
# Processing record 13 of set 11 | cumaral
# Processing record 14 of set 11 | vorozhba
# Processing record 15 of set 11 | toliary
# City not found. Skipping...
# Processing record 16 of set 11 | newport
# Processing record 17 of set 11 | senneterre
# Processing record 18 of set 11 | kralendijk
# Processing record 19 of set 11 | beloha
# Processing record 20 of set 11 | nuuk
# Processing record 21 of set 11 | tungor
# Processing record 22 of set 11 | sargur
# Processing record 23 of set 11 | hearst
# Processing record 24 of set 11 | bridlington
# Processing record 25 of set 11 | uromi
# Processing record 26 of set 11 | bundaberg
# Processing record 27 of set 11 | cockburn harbour
# City not found. Skipping...
# Processing record 28 of set 11 | phulji
# Processing record 29 of set 11 | mecca
# Processing record 30 of set 11 | sibolga
# Processing record 31 of set 11 | brae
# Processing record 32 of set 11 | dukat
# Processing record 33 of set 11 | obo
# Processing record 34 of set 11 | colac
# Processing record 35 of set 11 | wajir
# Processing record 36 of set 11 | athens
# Processing record 37 of set 11 | pumiao
# Processing record 38 of set 11 | ayan
# Processing record 39 of set 11 | loandjili
# Processing record 40 of set 11 | bangolo
# Processing record 41 of set 11 | anzio
# Processing record 42 of set 11 | karacakoy
# Processing record 43 of set 11 | sao felix do xingu
# Processing record 44 of set 11 | mitsamiouli
# Processing record 45 of set 11 | waingapu
# Processing record 46 of set 11 | santa maria
# Processing record 47 of set 11 | baruun-urt
# Processing record 48 of set 11 | savalou
# Processing record 49 of set 11 | ogulin
# Processing record 50 of set 11 | batticaloa
# Processing record 1 of set 12 | kharan
# Processing record 2 of set 12 | naze
# Processing record 3 of set 12 | rudbar
# Processing record 4 of set 12 | sayyan
# Processing record 5 of set 12 | jasper
# Processing record 6 of set 12 | lata
# Processing record 7 of set 12 | kaveripattinam
# Processing record 8 of set 12 | jalu
# Processing record 9 of set 12 | porto nacional
# Processing record 10 of set 12 | narsaq
# Processing record 11 of set 12 | praia
# Processing record 12 of set 12 | bristol
# Processing record 13 of set 12 | mount gambier
# Processing record 14 of set 12 | one hundred mile house
# City not found. Skipping...
# Processing record 15 of set 12 | warmbad
# Processing record 16 of set 12 | ancona
# Processing record 17 of set 12 | fare
# Processing record 18 of set 12 | palana
# Processing record 19 of set 12 | omboue
# Processing record 20 of set 12 | bauchi
# Processing record 21 of set 12 | lannion
# Processing record 22 of set 12 | ferrol
# Processing record 23 of set 12 | linchuan
# City not found. Skipping...
# Processing record 24 of set 12 | maarianhamina
# Processing record 25 of set 12 | santa isabel
# Processing record 26 of set 12 | gat
# Processing record 27 of set 12 | pitimbu
# Processing record 28 of set 12 | zhezkazgan
# Processing record 29 of set 12 | svilajnac
# Processing record 30 of set 12 | almenara
# Processing record 31 of set 12 | finschhafen
# Processing record 32 of set 12 | kerteh
# City not found. Skipping...
# Processing record 33 of set 12 | auki
# Processing record 34 of set 12 | camargo
# Processing record 35 of set 12 | murfreesboro
# Processing record 36 of set 12 | cap malheureux
# Processing record 37 of set 12 | campbell river
# Processing record 38 of set 12 | yerofey pavlovich
# Processing record 39 of set 12 | waipawa
# Processing record 40 of set 12 | sao domingos
# Processing record 41 of set 12 | onguday
# Processing record 42 of set 12 | sao luis do quitunde
# Processing record 43 of set 12 | bukoba
# Processing record 44 of set 12 | grand baie
# Processing record 45 of set 12 | les cayes
# Processing record 46 of set 12 | luanda
# Processing record 47 of set 12 | amapa
# Processing record 48 of set 12 | burnie
# Processing record 49 of set 12 | berezovyy
# Processing record 50 of set 12 | buraydah
# Processing record 1 of set 13 | natchitoches
# Processing record 2 of set 13 | bria
# Processing record 3 of set 13 | abu samrah
# Processing record 4 of set 13 | veraval
# Processing record 5 of set 13 | tambun
# Processing record 6 of set 13 | tandur
# Processing record 7 of set 13 | hambantota
# Processing record 8 of set 13 | innisfail
# Processing record 9 of set 13 | biltine
# Processing record 10 of set 13 | plettenberg bay
# Processing record 11 of set 13 | antalaha
# Processing record 12 of set 13 | lakes entrance
# Processing record 13 of set 13 | taree
# Processing record 14 of set 13 | kandrian
# Processing record 15 of set 13 | ambon
# Processing record 16 of set 13 | longmont
# Processing record 17 of set 13 | san carlos de bariloche
# Processing record 18 of set 13 | sao cristovao
# Processing record 19 of set 13 | fort nelson
# Processing record 20 of set 13 | bunia
# Processing record 21 of set 13 | bilibino
# Processing record 22 of set 13 | saryshagan
# City not found. Skipping...
# Processing record 23 of set 13 | meyungs
# City not found. Skipping...
# Processing record 24 of set 13 | geraldton
# Processing record 25 of set 13 | mikhaylovka
# Processing record 26 of set 13 | rio grande
# Processing record 27 of set 13 | kharitonovo
# Processing record 28 of set 13 | goderich
# Processing record 29 of set 13 | lyngseidet
# Processing record 30 of set 13 | kuala terengganu
# Processing record 31 of set 13 | ovsyanka
# Processing record 32 of set 13 | cariamanga
# Processing record 33 of set 13 | roncesvalles
# Processing record 34 of set 13 | vitim
# Processing record 35 of set 13 | kuche
# City not found. Skipping...
# Processing record 36 of set 13 | zhuhai
# Processing record 37 of set 13 | naushki
# Processing record 38 of set 13 | gazanjyk
# Processing record 39 of set 13 | arrifes
# Processing record 40 of set 13 | magadi
# Processing record 41 of set 13 | kedgwick
# Processing record 42 of set 13 | port lincoln
# Processing record 43 of set 13 | phonhong
# Processing record 44 of set 13 | maridi
# Processing record 45 of set 13 | juifang
# City not found. Skipping...
# Processing record 46 of set 13 | warqla
# City not found. Skipping...
# Processing record 47 of set 13 | atar
# Processing record 48 of set 13 | anadyr
# Processing record 49 of set 13 | raubling
# Processing record 50 of set 13 | pustoshka
# Processing record 1 of set 14 | mahon
# Processing record 2 of set 14 | nagato
# Processing record 3 of set 14 | oussouye
# Processing record 4 of set 14 | daru
# Processing record 5 of set 14 | kadykchan
# City not found. Skipping...
# Processing record 6 of set 14 | south yuba city
# Processing record 7 of set 14 | tarabha
# Processing record 8 of set 14 | chumikan
# Processing record 9 of set 14 | zdvinsk
# Processing record 10 of set 14 | nalut
# Processing record 11 of set 14 | sao joao da barra
# Processing record 12 of set 14 | hit
# Processing record 13 of set 14 | linkoping
# Processing record 14 of set 14 | bilma
# Processing record 15 of set 14 | jinhua
# Processing record 16 of set 14 | bizhbulyak
# Processing record 17 of set 14 | kostomuksha
# Processing record 18 of set 14 | norden
# Processing record 19 of set 14 | uspenskaya
# Processing record 20 of set 14 | poltavka
# Processing record 21 of set 14 | caraballeda
# Processing record 22 of set 14 | pangkalanbuun
# Processing record 23 of set 14 | sirjan
# Processing record 24 of set 14 | churapcha
# Processing record 25 of set 14 | benguela
# Processing record 26 of set 14 | kundgol
# Processing record 27 of set 14 | lasa
# Processing record 28 of set 14 | kamaishi
# Processing record 29 of set 14 | khasan
# Processing record 30 of set 14 | tshikapa
# Processing record 31 of set 14 | suhbaatar
# Processing record 32 of set 14 | maragogi
# Processing record 33 of set 14 | hanna
# Processing record 34 of set 14 | tianpeng
# Processing record 35 of set 14 | loiza
# Processing record 36 of set 14 | valparaiso
# Processing record 37 of set 14 | khonuu
# City not found. Skipping...
# Processing record 38 of set 14 | kismayo
# Processing record 39 of set 14 | rio gallegos
# Processing record 40 of set 14 | sai buri
# Processing record 41 of set 14 | terney
# Processing record 42 of set 14 | atbasar
# Processing record 43 of set 14 | quatre cocos
# Processing record 44 of set 14 | barranca
# Processing record 45 of set 14 | maniitsoq
# Processing record 46 of set 14 | clarence town
# Processing record 47 of set 14 | port macquarie
# Processing record 48 of set 14 | krasnyye barrikady
# Processing record 49 of set 14 | san vicente
# Processing record 50 of set 14 | bereda
# Processing record 1 of set 15 | kungurtug
# Processing record 2 of set 15 | altamira
# Processing record 3 of set 15 | sant julia de loria
# Processing record 4 of set 15 | la ronge
# Processing record 5 of set 15 | mugla
# Processing record 6 of set 15 | opuwo
# Processing record 7 of set 15 | tabou
# Processing record 8 of set 15 | deputatskiy
# Processing record 9 of set 15 | hurghada
# Processing record 10 of set 15 | shchelyayur
# City not found. Skipping...
# Processing record 11 of set 15 | ortakoy
# Processing record 12 of set 15 | tralee
# Processing record 13 of set 15 | umzimvubu
# City not found. Skipping...
# Processing record 14 of set 15 | qasigiannguit
# Processing record 15 of set 15 | luwuk
# Processing record 16 of set 15 | labytnangi
# Processing record 17 of set 15 | santa rosa
# Processing record 18 of set 15 | qobustan
# Processing record 19 of set 15 | liepaja
# Processing record 20 of set 15 | penarroya-pueblonuevo
# Processing record 21 of set 15 | steinbach
# Processing record 22 of set 15 | rorvik
# Processing record 23 of set 15 | huanren
# Processing record 24 of set 15 | karratha
# Processing record 25 of set 15 | ipixuna
# Processing record 26 of set 15 | mmathubudukwane
# Processing record 27 of set 15 | barcelona
# Processing record 28 of set 15 | selizharovo
# Processing record 29 of set 15 | esna
# Processing record 30 of set 15 | belmonte
# Processing record 31 of set 15 | shymkent
# Processing record 32 of set 15 | gobabis
# Processing record 33 of set 15 | bandarbeyla
# Processing record 34 of set 15 | isangel
# Processing record 35 of set 15 | muyezerskiy
# Processing record 36 of set 15 | chakradharpur
# Processing record 37 of set 15 | saint-pierre
# Processing record 38 of set 15 | grand-lahou
# Processing record 39 of set 15 | casma
# Processing record 40 of set 15 | lucea
# Processing record 41 of set 15 | roald
# Processing record 42 of set 15 | lazaro cardenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#          City Country      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0    Hermanus      ZA -34.4187   19.2345    288.64        71          56
# 1      Castro      BR -24.7911  -50.0119    287.77        95          18
# 2   Busselton      AU -33.6500  115.3333    286.94        86           0
# 3   Zhanaozen      KZ  43.3000   52.8000    284.01        52          70
# 4     Mataura      NZ -46.1927  168.8643    286.19        74           5
# 5     Winslow      US  35.0242 -110.6974    296.25         9           0
# 6     Cayenne      GF   4.9333  -52.3333    300.98         1          75
# 7     Ondjiva      AO -17.0667   15.7333    293.44        65           7
# 8  Sao Filipe      CV  14.8961  -24.4956    295.11        75           1
# 9      Mehran      IR  33.1222   46.1646    293.43        32          21
#
#    Wind Speed Current Description
# 0        3.71       broken clouds
# 1        2.68          few clouds
# 2        3.56           clear sky
# 3        0.61       broken clouds
# 4        1.01           clear sky
# 5       10.80           clear sky
# 6        5.66       broken clouds
# 7        2.26           clear sky
# 8        4.16           clear sky
# 9        3.32          light rain

# %%
output_file = 'WeatherPy_Database.csv'

city_data_df.to_csv(output_file, index_label='City ID')
